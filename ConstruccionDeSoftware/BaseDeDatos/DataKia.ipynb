-- %% [markdown]
-- # [dbo].[HistorialVerificacion]

-- %%
USE [dataKia]
GO

-- %%
/****** Object:  Table [dbo].[HistorialVerificacion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HistorialVerificacion](
	[id_historial] [int] NOT NULL,
	[id_jugador] [int] NULL,
	[fecha_verificacion] [date] NULL,
	[estado_verificacion] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_historial] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jugador]

-- %%
/****** Object:  Table [dbo].[Jugador]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jugador](
	[id_jugador] [int] NOT NULL,
	[nombre] [varchar](100) NULL,
	[correo_electronico] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_jugador] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoVerificacion]

-- %%
/****** Object:  Table [dbo].[TipoVerificacion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoVerificacion](
	[id_tipo_verificacion] [int] NOT NULL,
	[nombre_tipo] [varchar](100) NULL,
	[descripcion_tipo] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_verificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vw_JugadoresConVerificaciones]

-- %%
/****** Object:  View [dbo].[vw_JugadoresConVerificaciones]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vw_JugadoresConVerificaciones] AS
SELECT 
    j.id_jugador AS IdJugador,
    j.nombre AS NombreJugador,
    hv.fecha_verificacion AS FechaVerificacion,
    tv.nombre_tipo AS TipoVerificacion,
    hv.estado_verificacion AS EstadoVerificacion
FROM 
    Jugador j
INNER JOIN 
    HistorialVerificacion hv ON j.id_jugador = hv.id_jugador
INNER JOIN 
    TipoVerificacion tv ON hv.id_historial = tv.id_tipo_verificacion;
GO

-- %% [markdown]
-- # [dbo].[Empleado]

-- %%
/****** Object:  Table [dbo].[Empleado]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleado](
	[id] [int] NOT NULL,
	[puestoTrabajo] [varchar](100) NULL,
	[pausaTrabajo] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[id] [int] NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[apellido1] [varchar](100) NOT NULL,
	[apellido2] [varchar](100) NULL,
	[contrasena] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vw_EmpleadosConUsuarios]

-- %%
/****** Object:  View [dbo].[vw_EmpleadosConUsuarios]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vw_EmpleadosConUsuarios] AS
SELECT 
    e.id AS IdEmpleado,
    u.nombre AS NombreUsuario,
    u.apellido1 AS PrimerApellido,
    u.apellido2 AS SegundoApellido,
    e.puestoTrabajo AS PuestoTrabajo,
    e.pausaTrabajo AS PausaTrabajo
FROM 
    Empleado e
INNER JOIN 
    Usuario u ON e.id = u.id;
GO

-- %% [markdown]
-- # [dbo].[Chat]

-- %%
/****** Object:  Table [dbo].[Chat]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Chat](
	[id] [int] NOT NULL,
	[mensaje] [text] NULL,
	[emisor] [varchar](100) NULL,
	[receptor] [varchar](100) NULL,
	[fecha_hora] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConfiguracionChat]

-- %%
/****** Object:  Table [dbo].[ConfiguracionChat]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConfiguracionChat](
	[id_configuracion] [int] NOT NULL,
	[id_usuario] [int] NULL,
	[notificaciones_activadas] [bit] NULL,
	[estado_en_linea] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_configuracion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario_con_Chat]

-- %%
/****** Object:  View [dbo].[Usuario_con_Chat]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[Usuario_con_Chat]
AS
SELECT dbo.Usuario.id, dbo.Usuario.nombre, dbo.Usuario.apellido1, dbo.Chat.mensaje, dbo.Chat.emisor, dbo.Chat.receptor, dbo.ConfiguracionChat.id_configuracion, dbo.ConfiguracionChat.estado_en_linea, 
                  dbo.ConfiguracionChat.notificaciones_activadas
FROM     dbo.Usuario INNER JOIN
                  dbo.ConfiguracionChat ON dbo.Usuario.id = dbo.ConfiguracionChat.id_usuario INNER JOIN
                  dbo.Chat ON dbo.Usuario.id = dbo.Chat.id
GO

-- %% [markdown]
-- # [dbo].[DetallesEvento]

-- %%
/****** Object:  Table [dbo].[DetallesEvento]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetallesEvento](
	[id_tipo_evento] [int] NOT NULL,
	[evento] [varchar](100) NOT NULL,
	[fecha] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_evento] ASC,
	[evento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoEvento]

-- %%
/****** Object:  Table [dbo].[TipoEvento]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoEvento](
	[id_tipo_evento] [int] NOT NULL,
	[nombre_tipo] [varchar](100) NULL,
	[descripcion_tipo] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_evento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_de_Evento_con_Detalles_de_Evento]

-- %%
/****** Object:  View [dbo].[Tipo_de_Evento_con_Detalles_de_Evento]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[Tipo_de_Evento_con_Detalles_de_Evento]
AS
SELECT dbo.TipoEvento.id_tipo_evento, dbo.TipoEvento.nombre_tipo, dbo.TipoEvento.descripcion_tipo, dbo.DetallesEvento.evento, dbo.DetallesEvento.fecha
FROM     dbo.TipoEvento INNER JOIN
                  dbo.DetallesEvento ON dbo.TipoEvento.id_tipo_evento = dbo.DetallesEvento.id_tipo_evento
GO

-- %% [markdown]
-- # [dbo].[DetalleCompensacion]

-- %%
/****** Object:  Table [dbo].[DetalleCompensacion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleCompensacion](
	[id_tipo_compensacion] [int] NOT NULL,
	[evento_compensacion] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_compensacion] ASC,
	[evento_compensacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoCompensacion]

-- %%
/****** Object:  Table [dbo].[TipoCompensacion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoCompensacion](
	[id_tipo_compensacion] [int] NOT NULL,
	[nombre_tipo] [varchar](100) NULL,
	[descripcion_tipo] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_compensacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_de_Compensación_con_Tipo_de_compensación]

-- %%
/****** Object:  View [dbo].[Detalle_de_Compensación_con_Tipo_de_compensación]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[Detalle_de_Compensación_con_Tipo_de_compensación]
AS
SELECT dbo.DetalleCompensacion.id_tipo_compensacion, dbo.TipoCompensacion.nombre_tipo, dbo.DetalleCompensacion.evento_compensacion, dbo.TipoCompensacion.descripcion_tipo
FROM     dbo.DetalleCompensacion INNER JOIN
                  dbo.TipoCompensacion ON dbo.DetalleCompensacion.id_tipo_compensacion = dbo.TipoCompensacion.id_tipo_compensacion
GO

-- %% [markdown]
-- # [dbo].[Calendario]

-- %%
/****** Object:  Table [dbo].[Calendario]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Calendario](
	[evento] [varchar](100) NOT NULL,
	[fecha] [date] NULL,
	[descripcionEvento] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[evento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Escena]

-- %%
/****** Object:  Table [dbo].[Escena]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Escena](
	[nombre_escena] [varchar](100) NOT NULL,
	[id_escena] [int] NULL,
	[duracion_escena] [time](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[nombre_escena] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Historia]

-- %%
/****** Object:  Table [dbo].[Historia]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Historia](
	[num_escenas] [int] NOT NULL,
	[duracion_total_escenas] [time](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[num_escenas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HistorialMensajes]

-- %%
/****** Object:  Table [dbo].[HistorialMensajes]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HistorialMensajes](
	[id_mensaje] [int] NOT NULL,
	[emisor] [varchar](100) NULL,
	[receptor] [varchar](100) NULL,
	[fecha_hora] [datetime] NULL,
	[mensaje] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_mensaje] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Notificacion]

-- %%
/****** Object:  Table [dbo].[Notificacion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Notificacion](
	[id_notificacion] [int] NOT NULL,
	[fecha_notificacion] [date] NULL,
	[hora_notificacion] [time](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_notificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Videojuego]

-- %%
/****** Object:  Table [dbo].[Videojuego]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Videojuego](
	[titulo] [varchar](100) NOT NULL,
	[descripcion] [text] NULL,
	[progreso] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[titulo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Configura__id_us__5629CD9C]

-- %%
ALTER TABLE [dbo].[ConfiguracionChat]  WITH CHECK ADD FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuario] ([id])
GO

-- %% [markdown]
-- # [FK__DetalleCo__id_ti__571DF1D5]

-- %%
ALTER TABLE [dbo].[DetalleCompensacion]  WITH CHECK ADD FOREIGN KEY([id_tipo_compensacion])
REFERENCES [dbo].[TipoCompensacion] ([id_tipo_compensacion])
GO

-- %% [markdown]
-- # [FK__DetallesE__id_ti__5812160E]

-- %%
ALTER TABLE [dbo].[DetallesEvento]  WITH CHECK ADD FOREIGN KEY([id_tipo_evento])
REFERENCES [dbo].[TipoEvento] ([id_tipo_evento])
GO

-- %% [markdown]
-- # [FK__Empleado__id__59063A47]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD FOREIGN KEY([id])
REFERENCES [dbo].[Usuario] ([id])
GO

-- %% [markdown]
-- # [FK__Historial__id_ju__59FA5E80]

-- %%
ALTER TABLE [dbo].[HistorialVerificacion]  WITH CHECK ADD FOREIGN KEY([id_jugador])
REFERENCES [dbo].[Jugador] ([id_jugador])
GO

-- %% [markdown]
-- # [dbo].[actualizarPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarPerfil]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[actualizarPerfil]
    @Usuario NVARCHAR(100),
    @NuevoNombre NVARCHAR(100)
AS
BEGIN
    -- Lógica para actualizar el perfil del usuario
    UPDATE Usuarios
    SET Nombre = @NuevoNombre
    WHERE Nombre = @Usuario;
    PRINT 'Perfil actualizado para: ' + @Usuario;
END;
GO

-- %% [markdown]
-- # [dbo].[FPB_registrarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[FPB_registrarUsuario]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[FPB_registrarUsuario]
    @nombre varchar(100),
    @contrasena varchar(100)
AS
BEGIN
    INSERT INTO Usuario(nombre, contrasena)
    VALUES(@nombre, @contrasena)
END;
GO

-- %% [markdown]
-- # [dbo].[iniciarSesion]

-- %%
/****** Object:  StoredProcedure [dbo].[iniciarSesion]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[iniciarSesion]
    @Usuario NVARCHAR(100),
    @Contrasena NVARCHAR(100)
AS
BEGIN
    -- Lógica para iniciar sesión del usuario
    DECLARE @Exito BIT;
    SET @Exito = (SELECT CASE WHEN EXISTS (
        SELECT 1 FROM Usuarios WHERE Nombre = @Usuario AND Contrasena = @Contrasena
    ) THEN 1 ELSE 0 END);
    
    IF @Exito = 1
    BEGIN
        PRINT 'Inicio de sesión exitoso';
    END
    ELSE
    BEGIN
        PRINT 'Credenciales incorrectas';
    END
END;
GO

-- %% [markdown]
-- # [dbo].[XZG_OBTENER_DETALLES_EMPLEADO]

-- %%
/****** Object:  StoredProcedure [dbo].[XZG_OBTENER_DETALLES_EMPLEADO]    Script Date: 29/08/2024 08:52:06 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE   PROCEDURE [dbo].[XZG_OBTENER_DETALLES_EMPLEADO]
    @id INT
AS
BEGIN
    SELECT U.nombre, U.apellido1, U.apellido2, E.puestoTrabajo, E.pausaTrabajo
    FROM [dbo].[Usuario] U
    INNER JOIN [dbo].[Empleado] E ON U.id = E.id
    WHERE U.id = @id
END

EXEC [dbo].[XZG_OBTENER_DETALLES_EMPLEADO] @id = 1
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[40] 4[20] 2[20] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "DetalleCompensacion"
            Begin Extent = 
               Top = 7
               Left = 48
               Bottom = 126
               Right = 291
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "TipoCompensacion"
            Begin Extent = 
               Top = 105
               Left = 330
               Bottom = 246
               Right = 573
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Detalle_de_Compensación_con_Tipo_de_compensación'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Detalle_de_Compensación_con_Tipo_de_compensación'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[41] 4[26] 2[17] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "TipoEvento"
            Begin Extent = 
               Top = 7
               Left = 48
               Bottom = 148
               Right = 252
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "DetallesEvento"
            Begin Extent = 
               Top = 74
               Left = 331
               Bottom = 215
               Right = 525
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Tipo_de_Evento_con_Detalles_de_Evento'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Tipo_de_Evento_con_Detalles_de_Evento'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[47] 4[21] 2[23] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "Usuario"
            Begin Extent = 
               Top = 7
               Left = 48
               Bottom = 170
               Right = 242
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "ConfiguracionChat"
            Begin Extent = 
               Top = 7
               Left = 290
               Bottom = 170
               Right = 545
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "Chat"
            Begin Extent = 
               Top = 184
               Left = 282
               Bottom = 347
               Right = 476
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Usuario_con_Chat'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'Usuario_con_Chat'
GO
